# %%
import matplotlib.pyplot as plt
import numpy as np
from typing import List, Union, Optional

# %%
data = np.random.normal(size=10000)

# %%
def plot(x:np.ndarray, edges:Optional[Union[np.ndarray,List[float]]]=None) -> None:
    fig, axs = plt.subplots(1,2, figsize=(12,4))
    axs[0].hist(x, bins=edges, density=False)
    axs[1].hist(x, bins=edges, density=True)
    plt.show()

# %%
def get_edges(x:np.ndarray, min_unc:float) -> Union[np.ndarray,List[float]]:
    min_n = int(np.ceil(min_unc**-2))
    x.sort()
    edges = x[np.arange(0, len(x), min_n)]
    if edges[-1] != x[-1]: edges = list(edges) + [x[-1]]
    return edges

# %%
plot(data)

# %%
edges = get_edges(data, 0.05); len(edges), edges[0], edges[-1]
# Out:
# (26, -3.785449903787499, 3.603151161124292)

# %%
plot(data, edges)
